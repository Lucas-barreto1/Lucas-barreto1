# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas-barreto1/Lucas-barreto1/blob/main/web-scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'}

url = 'https://br.investing.com/equities/brazil'
request  = requests.get(url, headers=header)

df = pd.read_html(request.text)
df
# Out:
# [    Unnamed: 0                Nome  Último  Máxima  Mínima  Variação    Var%  \
#  0          NaN             Rumo ON    1891    1993    1871      -105  -5,26%
#  1          NaN       Alpargatas PN    1610    1696    1584       -69  -4,11%
#  2          NaN            Ambev ON    1577    1607    1569       -27  -1,68%
#  3          NaN           Arezzo ON    8686    9088    8601      -384  -4,23%
#  4          NaN  Banco do Brasil ON    3421    3523    3392       -81  -2,31%
#  ..         ...                 ...     ...     ...     ...       ...     ...
#  87         NaN        Rede D'Or ON    2964    3113    2913      -172  -5,48%
#  88         NaN    CSN Mineração ON     360     377     358        -4  -1,10%
#  89         NaN            Assaí ON    1921    1989    1912       -60  -3,03%
#  90         NaN           Raizen PN     405     419     399       -10  -2,41%
#  91         NaN        Iguatemi Unt    1836    1930    1829       -76  -3,97%
#
#         Vol.   Hora  Unnamed: 9
# ...

# %%
for i , tabela in enumerate(df):
  print('----------------------')
  print(i)
  print(tabela)
# Out:
# ----------------------
# 0
#     Unnamed: 0                Nome  Último  Máxima  Mínima  Variação    Var%  \
# 0          NaN             Rumo ON    1891    1993    1871      -105  -5,26%
# 1          NaN       Alpargatas PN    1610    1696    1584       -69  -4,11%
# 2          NaN            Ambev ON    1577    1607    1569       -27  -1,68%
# 3          NaN           Arezzo ON    8686    9088    8601      -384  -4,23%
# 4          NaN  Banco do Brasil ON    3421    3523    3392       -81  -2,31%
# ..         ...                 ...     ...     ...     ...       ...     ...
# 87         NaN        Rede D'Or ON    2964    3113    2913      -172  -5,48%
# 88         NaN    CSN Mineração ON     360     377     358        -4  -1,10%
# 89         NaN            Assaí ON    1921    1989    1912       -60  -3,03%
# 90         NaN           Raizen PN     405     419     399       -10  -2,41%
# 91         NaN        Iguatemi Unt    1836    1930    1829       -76  -3,97%
#
# ...

# %%
df = pd.DataFrame(df[0])

# %%
df
# Out:
#     Unnamed: 0                Nome  Último  Máxima  Mínima  Variação    Var%  \
# 0          NaN             Rumo ON    1891    1993    1871      -105  -5,26%
# 1          NaN       Alpargatas PN    1610    1696    1584       -69  -4,11%
# 2          NaN            Ambev ON    1577    1607    1569       -27  -1,68%
# 3          NaN           Arezzo ON    8686    9088    8601      -384  -4,23%
# 4          NaN  Banco do Brasil ON    3421    3523    3392       -81  -2,31%
# ..         ...                 ...     ...     ...     ...       ...     ...
# 87         NaN        Rede D'Or ON    2964    3113    2913      -172  -5,48%
# 88         NaN    CSN Mineração ON     360     377     358        -4  -1,10%
# 89         NaN            Assaí ON    1921    1989    1912       -60  -3,03%
# 90         NaN           Raizen PN     405     419     399       -10  -2,41%
# 91         NaN        Iguatemi Unt    1836    1930    1829       -76  -3,97%
#
#        Vol.   Hora  Unnamed: 9
# ...

# %%
df['Último'] = df['Último'] /100

# %%
df['Máxima'] = df['Máxima'] /100

# %%
df['Mínima'] = df['Mínima'] /100

# %%
df
# Out:
#     Unnamed: 0                Nome  Último  Máxima  Mínima  Variação    Var%  \
# 0          NaN             Rumo ON   18.91   19.93   18.71      -105  -5,26%
# 1          NaN       Alpargatas PN   16.10   16.96   15.84       -69  -4,11%
# 2          NaN            Ambev ON   15.77   16.07   15.69       -27  -1,68%
# 3          NaN           Arezzo ON   86.86   90.88   86.01      -384  -4,23%
# 4          NaN  Banco do Brasil ON   34.21   35.23   33.92       -81  -2,31%
# ..         ...                 ...     ...     ...     ...       ...     ...
# 87         NaN        Rede D'Or ON   29.64   31.13   29.13      -172  -5,48%
# 88         NaN    CSN Mineração ON    3.60    3.77    3.58        -4  -1,10%
# 89         NaN            Assaí ON   19.21   19.89   19.12       -60  -3,03%
# 90         NaN           Raizen PN    4.05    4.19    3.99       -10  -2,41%
# 91         NaN        Iguatemi Unt   18.36   19.30   18.29       -76  -3,97%
#
#        Vol.   Hora  Unnamed: 9
# ...
